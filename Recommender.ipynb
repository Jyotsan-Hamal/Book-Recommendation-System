# %%
import pandas as pd
import numpy as np

# %%
books = pd.read_csv('books.csv')
users = pd.read_csv('users.csv')
ratings = pd.read_csv('ratings.csv')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10596\3819754567.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('books.csv')

# %%
books.head(6)
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
# 5  0399135782                             The Kitchen God's Wife
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
# 5               Amy Tan                1991            Putnam Pub Group
#
# ...

# %%
users.head(6)
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN
# 5        6       santa monica, california, usa  61.0

# %%
ratings.head(6)
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6
# 5   276733  2080674722            0

# %% [markdown]
# ## Knowledge we have uncovered from Dataframe:
# - there are three csv
#   - books
#   - ratings
#   - users
# - books_df description:
#   - this dataframe has ISBN, Book-titles,Authors, URLS
#   - no duplicated value
#   - It's a simple data with ISBN and their respective book details
# - ratings_df description:
#   - this dataframe has User-ID, Book-title, ratings
#   - this dataframe has multiple user rating multiple books

# %% [markdown]
# ## Things we are doing
# - we need to find out the avg rating of each books and see which on is most popular
# - we will see the books with avf rating on descending order.

# %%
print(ratings['User-ID'].nunique())
print(ratings['ISBN'].nunique())
# Out:
# 105283
# 340556

# %% [markdown]
# #### We will merge the ratings with books dataframe

# %%
book_ratings = ratings.merge(books,on="ISBN")

# %%
book_ratings.head(3)
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 2     6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
#
#   Year-Of-Publication         Publisher  \
# 0                2002  Ballantine Books
# 1                2002  Ballantine Books
# 2                2002  Ballantine Books
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-L
# ...

# %% [markdown]
# #### we will use groupby operation on Book-title and see the count of number of rating each book has got

# %%
book_ratings.groupby("Book-Title").count()
# Out:
#                                                     User-ID  ISBN  \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...        4     4
#  Always Have Popsicles                                    1     1
#  Apple Magic (The Collector's series)                     1     1
#  Ask Lily (Young Women of Faith: Lily Series, B...        1     1
#  Beyond IBM: Leadership Marketing and Finance f...        1     1
# ...                                                     ...   ...
# Ã?Â?lpiraten.                                             2     2
# Ã?Â?rger mit Produkt X. Roman.                            4     4
# Ã?Â?sterlich leben.                                       1     1
# Ã?Â?stlich der Berge.                                     3     3
# Ã?Â?thique en toc                                         2     2
#
#                                                     Book-Rating  Book-Author  \
# Book-Title
# ...

# %% [markdown]
# ## Below code takes the number of book ratings and forms a new dataframe using:
# - reset_index()

# %%
books_with_no_of_ratings = book_ratings.groupby("Book-Title").count()['Book-Rating'].reset_index()

# %% [markdown]
# #### Now renaming the dataframe

# %%
books_with_no_of_ratings.rename(columns={"Book-Rating":"num_ratings"},inplace=True)
books_with_no_of_ratings
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %% [markdown]
# #### Again doing the groupby operation on Book-rating but with mean approach.

# %%
books_with_avg_no_of_ratings = book_ratings[["Book-Rating","Book-Title"]].groupby("Book-Title").mean().reset_index()
books_with_avg_no_of_ratings.rename(columns={"Book-Rating":"avg_num_ratings"},inplace=True)
books_with_avg_no_of_ratings
# Out:
#                                                Book-Title  avg_num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...         2.250000
# 1                                   Always Have Popsicles         0.000000
# 2                    Apple Magic (The Collector's series)         0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...         8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...         0.000000
# ...                                                   ...              ...
# 241066                                      Ã?Â?lpiraten.         0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.         5.250000
# 241068                                Ã?Â?sterlich leben.         7.000000
# 241069                              Ã?Â?stlich der Berge.         2.666667
# 241070                                  Ã?Â?thique en toc         4.000000
#
# [241071 rows x 2 columns]

# %% [markdown]
# ## Now let's merge both of them

# %%
popular_book_df = books_with_no_of_ratings.merge(books_with_avg_no_of_ratings,on="Book-Title")

# %% [markdown]
# ## Now we only want books with number of rating more than 250.
# - we also sorted the books in descending order on the basis of "avg_num_ratings" columns

# %%
popular_book_df = popular_book_df[popular_book_df['num_ratings']>=250].sort_values("avg_num_ratings",ascending=False)

# %%
popular_book_df.head(40)
# Out:
#                                                Book-Title  num_ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 80422        Harry Potter and the Goblet of Fire (Book 4)          387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)          278
# 80426   Harry Potter and the Order of the Phoenix (Boo...          347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)          556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...          281
# 187377  The Fellowship of the Ring (The Lord of the Ri...          368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 211384     The Two Towers (The Lord of the Rings, Part 2)          260
# 219741                              To Kill a Mockingbird          510
# 183573                                  The Da Vinci Code          898
# 187880                 The Five People You Meet in Heaven          430
# ...

# %%
popular_book_df.merge(books,on="Book-Title").drop_duplicates("Book-Title")[['Book-Title','num_ratings','avg_num_ratings','Book-Author']]
# Out:
#                                             Book-Title  num_ratings  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 3         Harry Potter and the Goblet of Fire (Book 4)          387
# 5       Harry Potter and the Sorcerer's Stone (Book 1)          278
# 9    Harry Potter and the Order of the Phoenix (Boo...          347
# 13    Harry Potter and the Chamber of Secrets (Book 2)          556
# ..                                                 ...          ...
# 716       Vinegar Hill (Oprah's Book Club (Paperback))          265
# 717                                           Whispers          286
# 727                                  Presumed Innocent          294
# 733                                       Isle of Dogs          288
# 739                                        Wild Animus         2502
#
#      avg_num_ratings        Book-Author
# 0           5.852804      J. K. Rowling
# 3           5.824289      J. K. Rowling
# ...

# %% [markdown]
# # Above shows the popularity based recommendation system
# - used average rating system

# %% [markdown]
# ## Below lies the collaborative filtering system

# %%
book_ratings.head(5)
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 2     6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 3     8680  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 4    10314  034545104X            9  Flesh Tones: A Novel  M. J. Rose
#
#   Year-Of-Publication         Publisher  \
# 0                2002  Ballantine Books
# 1                2002  Ballantine Books
# 2                2002  Ballantine Books
# 3                2002  Ballantine Books
# 4                2002  Ballantine Books
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# ...

# %% [markdown]
# #### Now, we will use groupby method on User-ID to take out those users who has voted the books more than 200 times

# %%
x = book_ratings.groupby('User-ID').count()['Book-Rating']>200
usersID_who_voted_more_than_200 = x[x].index

# %%
users_voted_more_than_200_times =  book_ratings[book_ratings['User-ID'].isin(usersID_who_voted_more_than_200)]

# %%
users_voted_more_than_200_times.head(5)
# Out:
#     User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 2      6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 5     23768  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 7     28523  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 15    77940  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 16    81977  034545104X            0  Flesh Tones: A Novel  M. J. Rose
#
#    Year-Of-Publication         Publisher  \
# 2                 2002  Ballantine Books
# 5                 2002  Ballantine Books
# 7                 2002  Ballantine Books
# 15                2002  Ballantine Books
# 16                2002  Ballantine Books
#
#                                           Image-URL-S  \
# 2   http://images.amazon.com/images/P/034545104X.0...
# 5   http://images.amazon.com/images/P/034545104X.0...
# 7   http://images.amazon.com/images/P/034545104X.0...
# 15  http://images.amazon.com/images/P/034545104X.0...
# ...

# %% [markdown]
# #### Now we will use groupby on Book-title for those books which has been rated more than 50 times by users.

# %%
y = users_voted_more_than_200_times.groupby("Book-Title").count()['Book-Rating']>50
index_of_books_which_has_been_rated_more_than_50_times = y[y].index

# %%
index_of_books_which_has_been_rated_more_than_50_times
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Day Late and a Dollar Short', 'A Fine Balance',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=679)

# %%
final_df = users_voted_more_than_200_times[users_voted_more_than_200_times['Book-Title'].isin(index_of_books_which_has_been_rated_more_than_50_times)]

# %%
dump_df = final_df.drop_duplicates('Book-Title')

# %%
final_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Pivot Table function will make a rows as 'Book-Title' and columns as 'User-ID' and inside those 'Book-Rating'

# %%
pivot_table = final_df.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pivot_table.shape
# Out:
# (679, 810)

# %% [markdown]
# #### User = 679
# #### Books = 810

# %%
pivot_table.fillna(0,inplace=True)

# %%
pivot_table
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %% [markdown]
# ### As you can see the book has became vectors of len = 810.
# - each books vector is 810 and now we can see cosine similarity between each books

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Similarity Scores of each 679 books with 679 books

# %%
similarity = cosine_similarity(pivot_table)

# %%
similarity.shape
# Out:
# (679, 679)

# %% [markdown]
# ### Now we use similarity matrix for choosing the top 5 closest books
# - np.where provides the index of book_name provided by user in our pivot_table
# - then we use similarity matrix to find out the similarity scores
# - we enumerates the scores because it includes both scores and index position
# - then we sort the similarity_scores_with_indexes in descending order
# - takeout only top5 books
# - suggest them

# %%
def recommend(book_name):
    index_position = np.where(pivot_table.index==book_name)[0][0]
    
    similarity_scores_ = similarity[index_position]
    
    similarity_scores_with_indexes = list(enumerate(similarity_scores_))
    reverse_sorted_similarity_scores_with_indexes = sorted(similarity_scores_with_indexes,reverse=True,key=lambda x:x[1])
    top5_books = reverse_sorted_similarity_scores_with_indexes[0:6]
   
    suggestion = [book_name]
    books = []

    for i in top5_books:
        
#         print(dump_df.iloc[i[0]]['Book-Title'])
#         print( dump_df[dump_df['Book-Title']==pivot_table.index[i[0]]] )
        
        books.append([ pivot_table.index[i[0]], (1-i[1]) ])
    suggestion.append(books[1:])
    return suggestion

# %%
recommend("Where the Heart Is (Oprah's Book Club (Paperback))")
# Out:
# ["Where the Heart Is (Oprah's Book Club (Paperback))",
#  [['Blue Diary', 0.7066704391186633],
#   ['The Lovely Bones: A Novel', 0.7258252721924163],
#   ['I Know This Much Is True', 0.742740763134136],
#   ['Icy Sparks', 0.7581389557327153],
#   ['Deck the Halls (Holiday Classics)', 0.7794012662049634]]]

# %%
dump_df.iloc[607]['Book-Title']
# Out:
# 'The Bourne Identity'

# %%
recommend("The Two Towers (The Lord of the Rings, Part 2)")
# Out:
#         User-ID        ISBN  Book-Rating  \
# 196995      254  0618002235            0
#
#                                             Book-Title       Book-Author  \
# 196995  The Two Towers (The Lord of the Rings, Part 2)  J. R. R. Tolkien
#
#        Year-Of-Publication                 Publisher  \
# 196995                1999  Houghton Mifflin Company
#
#                                               Image-URL-S  \
# 196995  http://images.amazon.com/images/P/0618002235.0...
#
#                                               Image-URL-M  \
# 196995  http://images.amazon.com/images/P/0618002235.0...
#
#                                               Image-URL-L
# 196995  http://images.amazon.com/images/P/0618002235.0...
#         User-ID        ISBN  Book-Rating  \
# 128261    11676  0618129030            8
#
#                                                Book-Title       Book-Author  \
# 128261  The Fellowship of the Ring (The Lord of the Ri...  J. R. R. Tolkien
#
# ...

# %%
import pickle

# %%
dashboards = popular_book_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')

# %%
pickle.dump(dashboards,open('dashboard.pkl','wb'))

# %%
final_df
# Out:
#          User-ID        ISBN  Book-Rating              Book-Title  \
# 63        278418  0446520802            0            The Notebook
# 65          3363  0446520802            0            The Notebook
# 66          7158  0446520802           10            The Notebook
# 69         11676  0446520802           10            The Notebook
# 74         23768  0446520802            6            The Notebook
# ...          ...         ...          ...                     ...
# 1026724   266865  0531001725           10  The Catcher in the Rye
# 1027923   269566  0670809381            0                  Echoes
# 1028777   271284  0440910927            0           The Rainmaker
# 1029070   271705  B0001PIOX4            0          Fahrenheit 451
# 1030868   275970  1586210661            9  Me Talk Pretty One Day
#
#                    Book-Author Year-Of-Publication                Publisher  \
# 63             Nicholas Sparks                1996             Warner Books
# ...

# %%
pickle.dump(similarity,open('similarity.pkl','wb'))
